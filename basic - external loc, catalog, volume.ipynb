# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS banklocation
URL 'abfss://capstone-bankdata@parkaru20sa.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `project-cred`)
COMMENT 'External Location for bank data';

# %%
# %sql
CREATE CATALOG IF NOT EXISTS bankcatalog
MANAGED LOCATION 'abfss://capstone-bankdata@parkaru20sa.dfs.core.windows.net/'
COMMENT 'Bank Data CATALOG';

# %%
# %sql
USE CATALOG bankcatalog;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bankbronze;
CREATE SCHEMA IF NOT EXISTS banksilver;
CREATE SCHEMA IF NOT EXISTS bankgold;

# %%
# %sql
USE SCHEMA bankbronze;

# %%
# %sql
DROP VOLUME bank_data_volume;

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS bank_data_volume
  LOCATION 'abfss://capstone-bankdata@parkaru20sa.dfs.core.windows.net/bank_fetched_data/';
